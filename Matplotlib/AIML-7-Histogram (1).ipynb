# %%
import matplotlib.pyplot as plt
import numpy as np

ml_student = np.random.randint(18, 28, 100)

bins = [18, 20, 22, 24, 26, 28]

plt.hist(ml_student,
         bins=bins,
         rwidth=0.9,
         color='green',
         edgecolor='black',
         histtype = 'barstacked',
         orientation = 'horizontal')

plt.title("ML Student Age")
plt.xlabel("Student Age")
plt.ylabel("Number of Students")
#plt.legend()

plt.show()

# %%
plt.hist(ml_student,
         bins=bins,
         rwidth=0.9)
# Out:
# (array([24., 20., 15., 24., 17.]),
#  array([18., 20., 22., 24., 26., 28.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(ml_student,
         bins=bins,
         rwidth=0.9,
         color='green',
         edgecolor='black',
         histtype = 'barstacked',
         #orientation = 'horizontal',
         label = 'ml student')

plt.hist(py_student,
         bins=bins,
         rwidth=0.9,
         color='teal',
         edgecolor='black',
         histtype = 'barstacked',
         #orientation = 'horizontal',
         label = 'py student')

plt.legend()
plt.show()

# %%
plt.hist([ml_student,py_student],
         bins=bins,
         rwidth=0.9,
         color = ['green','teal'],
         edgecolor='black',
         histtype = 'barstacked',
         #orientation = 'horizontal',
         label = ['ml_student','py student'])
plt.legend()

# %%
plt.subplot()
# Out:
# <Axes: >
